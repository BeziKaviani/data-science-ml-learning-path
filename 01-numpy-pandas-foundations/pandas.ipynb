# %%
import pandas as pd
import numpy as np

# %% [markdown]
# CSV stands for Comma Separated Values

# %%
melb_data = pd.read_csv('datasets/melb_data/melb_data.csv')

# %% [markdown]
# For working with datas you have to convert it into pandas series at first

# %%
fruits = pd.Series(['Apple','Avacado','Banana','Cherry'])
fruits
# Out:
# 0      Apple
# 1    Avacado
# 2     Banana
# 3     Cherry
# dtype: object

# %%
fruits[0]
# Out:
# 'Apple'

# %%
floated_numbers = pd.Series([1.6, 7.2, 8.3, 19.3])
floated_numbers
# Out:
# 0     1.6
# 1     7.2
# 2     8.3
# 3    19.3
# dtype: float64

# %% [markdown]
# As you can see the type changes as the elements inside
# Because it uses C programming language

# %%
integer_numbers = pd.Series([1, 7, 3, 19])
integer_numbers
# Out:
# 0     1
# 1     7
# 2     3
# 3    19
# dtype: int64

# %%
fruits = pd.Series({
    'f1': "Apple",
    'f2': "Banana",
    'f3': "Avacado"
})
fruits
# Out:
# f1      Apple
# f2     Banana
# f3    Avacado
# dtype: object

# %% [markdown]
# Like working with dictionaries

# %%
fruits['f1']
# Out:
# 'Apple'

# %% [markdown]
# Although we are using dictionaries we can use indexing with iloc[] method

# %%
fruits.iloc[1]
# Out:
# 'Banana'

# %%
print(f"indexes: {fruits.index}")
print(f"values: {fruits.values}")
# Out:
# indexes: Index(['f1', 'f2', 'f3'], dtype='object')
# values: ['Apple' 'Banana' 'Avacado']

# %%
books = pd.Series(['Romance','Science','Adventure','Historic'], index=['b1','b2','b3','b4'])
books
# Out:
# b1      Romance
# b2      Science
# b3    Adventure
# b4     Historic
# dtype: object

# %% [markdown]
# We can use numpy methods on pandas series

# %%
weights = pd.Series([108,156,119,99,130])
np.sum(weights)
# Out:
# 612

# %%
fruits_1 = pd.Series({
    "name": "Apple",
    "color": "Red",
    "price": 2
})
fruits_2 = pd.Series({
    "name": "Banana",
    "color": "Yellow",
    "price": 4
})
fruits_3 = pd.Series({
    "name": "Cherry",
    "color": "Red",
    "price": 1
})

# %% [markdown]
# We can create dataframe by using DataFrame method and give it a list of pd series and indexs
# ([series], index=[])

# %%
fruit_df = pd.DataFrame([fruits_1, fruits_2, fruits_3], index=['f1', 'f2', 'f3'])
fruit_df
# Out:
#       name   color  price
# f1   Apple     Red      2
# f2  Banana  Yellow      4
# f3  Cherry     Red      1

# %%
fruit_df.loc['f1']
# Out:
# name     Apple
# color      Red
# price        2
# Name: f1, dtype: object

# %%
fruit_df.loc['f1', 'price']
# Out:
# 2

# %%
fruit_df.iloc[0,0]
# Out:
# 'Apple'

# %%
fruit_df['price']['f1']
# Out:
# 2

# %%
fruit_df.T
# Out:
#           f1      f2      f3
# name   Apple  Banana  Cherry
# color    Red  Yellow     Red
# price      2       4       1

# %%
fruit_df[['name']]
# Out:
#       name
# f1   Apple
# f2  Banana
# f3  Cherry

# %% [markdown]
# Deleting a row from dataframe

# %%
fruit_df.drop('f1', inplace=True)
fruit_df
# Out:
#       name   color  price
# f2  Banana  Yellow      4
# f3  Cherry     Red      1

# %%
melb_data = pd.read_csv("datasets/melb_data/melb_data.csv")
melb_data
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %% [markdown]
# The number of rows in this dataset

# %%
len(melb_data)
# Out:
# 18396

# %% [markdown]
# Shows the columns of this dataset

# %%
melb_data.columns
# Out:
# Index(['Unnamed: 0', 'Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method',
#        'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom',
#        'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea',
#        'Lattitude', 'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %% [markdown]
# Selecting a part with SellerG = Biggin and creating a new dataset from it

# %%
melb_data_Biggin = melb_data[melb_data['SellerG'] == "Biggin"]
melb_data_Biggin
# Out:
#        Unnamed: 0         Suburb             Address  Rooms Type      Price  \
# 0               1     Abbotsford        85 Turner St      2    h  1480000.0
# 1               2     Abbotsford     25 Bloomburg St      2    h  1035000.0
# 2               4     Abbotsford        5 Charles St      3    h  1465000.0
# 3               5     Abbotsford    40 Federation La      3    h   850000.0
# 10             17     Abbotsford  6/241 Nicholson St      1    u   300000.0
# ...           ...            ...                 ...    ...  ...        ...
# 18262       23383        Prahran      69 Greville St      4    h  2668000.0
# 18281       23404       Richmond       170 Coppin St      4    h  1800000.0
# 18291       23418       Rowville      8 Lakeside Bvd      3    h   905000.0
# 18312       23443    South Yarra     8/37 Darling St      1    u   385000.0
# 18373       23515  Vermont South     308 Hawthorn Rd      3    t   931000.0
#
# ...

# %% [markdown]
# Only the top 5 rows

# %%
melb_data.head()
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
#
#   SellerG       Date  Distance  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  Biggin  3/12/2016       2.5  ...       1.0  1.0     202.0           NaN
# 1  Biggin  4/02/2016       2.5  ...       1.0  0.0     156.0          79.0
# 2  Biggin  4/03/2017       2.5  ...       2.0  0.0     134.0         150.0
# 3  Biggin  4/03/2017       2.5  ...       2.0  1.0      94.0           NaN
# 4  Nelson  4/06/2016       2.5  ...       1.0  2.0     120.0         142.0
#
# ...

# %% [markdown]
# Only the last 5 rows

# %%
melb_data.tail()
# Out:
#        Unnamed: 0        Suburb          Address  Rooms Type      Price  \
# 18391       23540  Williamstown  8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown     96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie     17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville       6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville    33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# 18391     SP        Greg  26/08/2017       6.8  ...       2.0  1.0       NaN
# 18392     PI     Sweeney  26/08/2017       6.8  ...       1.0  5.0     866.0
# 18393      S  Buckingham  26/08/2017      12.7  ...       3.0  2.0       NaN
# 18394     SP     Village  26/08/2017       6.3  ...       1.0  1.0     362.0
# 18395     VB     Village  26/08/2017       6.3  ...       2.0  2.0       NaN
#
#        BuildingArea  YearBuilt  CouncilArea  Lattitude Longtitude  \
# ...

# %%
melb_data.count
# Out:
# <bound method DataFrame.count of        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
# ...

# %% [markdown]
# Counts the not Null values of each column

# %%
melb_data.count()
# Out:
# Unnamed: 0       18396
# Suburb           18396
# Address          18396
# Rooms            18396
# Type             18396
# Price            18396
# Method           18396
# SellerG          18396
# Date             18396
# Distance         18395
# Postcode         18395
# Bedroom2         14927
# Bathroom         14925
# Car              14820
# Landsize         13603
# BuildingArea      7762
# YearBuilt         8958
# CouncilArea      12233
# Lattitude        15064
# Longtitude       15064
# Regionname       18395
# Propertycount    18395
# dtype: int64

# %%
melb_data['Price'].count()
# Out:
# 18396

# %%
new_melb_data = melb_data[(melb_data['Price'] > 1000000) & (melb_data['SellerG'] == 'Biggin')]
new_melb_data
# Out:
#        Unnamed: 0        Suburb            Address  Rooms Type      Price  \
# 0               1    Abbotsford       85 Turner St      2    h  1480000.0
# 1               2    Abbotsford    25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford       5 Charles St      3    h  1465000.0
# 11             18    Abbotsford      10 Valiant St      2    h  1097000.0
# 18             26    Abbotsford         22 Park St      4    h  1985000.0
# ...           ...           ...                ...    ...  ...        ...
# 17732       22727      Richmond  106 Buckingham St      3    h  1600000.0
# 17933       22981     Braybrook      44 Carlton St      3    h  1200000.0
# 18209       23317  Moonee Ponds        53 Moore St      4    h  1305000.0
# 18262       23383       Prahran     69 Greville St      4    h  2668000.0
# 18281       23404      Richmond      170 Coppin St      4    h  1800000.0
#
#       Method SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
melb_data.describe
# Out:
# <bound method NDFrame.describe of        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
# ...

# %% [markdown]
# Gives some information about the dataset

# %%
melb_data.describe()
# Out:
#          Unnamed: 0         Rooms         Price      Distance      Postcode  \
# count  18396.000000  18396.000000  1.839600e+04  18395.000000  18395.000000
# mean   11826.787073      2.935040  1.056697e+06     10.389986   3107.140147
# std     6800.710448      0.958202  6.419217e+05      6.009050     95.000995
# min        1.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     5936.750000      2.000000  6.330000e+05      6.300000   3046.000000
# 50%    11820.500000      3.000000  8.800000e+05      9.700000   3085.000000
# 75%    17734.250000      3.000000  1.302000e+06     13.300000   3149.000000
# max    23546.000000     12.000000  9.000000e+06     48.100000   3978.000000
#
#            Bedroom2      Bathroom           Car       Landsize  BuildingArea  \
# count  14927.000000  14925.000000  14820.000000   13603.000000   7762.000000
# mean       2.913043      1.538492      1.615520     558.116371    151.220219
# ...

# %% [markdown]
# Shows the type and attributes of the dataset

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18396 entries, 0 to 18395
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     18396 non-null  int64
#  1   Suburb         18396 non-null  object
#  2   Address        18396 non-null  object
#  3   Rooms          18396 non-null  int64
#  4   Type           18396 non-null  object
#  5   Price          18396 non-null  float64
#  6   Method         18396 non-null  object
#  7   SellerG        18396 non-null  object
#  8   Date           18396 non-null  object
#  9   Distance       18395 non-null  float64
#  10  Postcode       18395 non-null  float64
#  11  Bedroom2       14927 non-null  float64
#  12  Bathroom       14925 non-null  float64
#  13  Car            14820 non-null  float64
#  14  Landsize       13603 non-null  float64
#  15  BuildingArea   7762 non-null   float64
#  16  YearBuilt      8958 non-null   float64
# ...

# %% [markdown]
# Sum of a column

# %%
melb_data['Price'].sum()
# Out:
# 19439006491.0

# %% [markdown]
# Variance of a column

# %%
melb_data['Price'].var()
# Out:
# 412063426191.144
