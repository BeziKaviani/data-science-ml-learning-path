# %%
import pandas as pd
import numpy as np
import scipy
import scipy.stats as sp
import matplotlib.pyplot as plt
from matplotlib import ticker
import seaborn as sns
import os

from matplotlib.lines import lineStyles

# %%
src_file = os.path.join("datasets","vehicles.csv")

# %%
df = pd.read_csv(src_file)
# Out:
# /tmp/ipykernel_6971/541733838.py:1: DtypeWarning: Columns (72,74,75,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(src_file)

# %%
df
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      14.167143         0.0        0.0        0.0      19      0.0        0
# 1      27.046364         0.0        0.0        0.0       9      0.0        0
# 2      11.018889         0.0        0.0        0.0      23      0.0        0
# 3      27.046364         0.0        0.0        0.0      10      0.0        0
# 4      15.658421         0.0        0.0        0.0      17      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 47697  13.523182         0.0        0.0        0.0      19      0.0        0
# 47698  12.935217         0.0        0.0        0.0      20      0.0        0
# 47699  14.167143         0.0        0.0        0.0      18      0.0        0
# 47700  14.167143         0.0        0.0        0.0      18      0.0        0
# 47701  16.528333         0.0        0.0        0.0      16      0.0        0
#
# ...

# %%
plt.hist(df['comb08'])
# Out:
# (array([25690., 20086.,   995.,   161.,   112.,   182.,   173.,   179.,
#            90.,    34.]),
#  array([  7. ,  20.5,  34. ,  47.5,  61. ,  74.5,  88. , 101.5, 115. ,
#         128.5, 142. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["comb08"])
plt.xlabel("Galons per mile")
plt.ylabel("Number of cars")
plt.title("Combined fuel economy")
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(df["comb08"])
# Out:
# (array([25690., 20086.,   995.,   161.,   112.,   182.,   173.,   179.,
#            90.,    34.]),
#  array([  7. ,  20.5,  34. ,  47.5,  61. ,  74.5,  88. , 101.5, 115. ,
#         128.5, 142. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'])
ax.set_xlabel("Galons per mile")
ax.set_ylabel("Number of cars")
ax.set_title("Combined fuel economy")
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'])
ax.set(xlabel='Galons per mile',
       ylabel='Number of cars',
       title='Combined fuel economy')
# Out:
# [Text(0.5, 0, 'Galons per mile'),
#  Text(0, 0.5, 'Number of cars'),
#  Text(0.5, 1.0, 'Combined fuel economy')]

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'],range=(10,15))
# Out:
# (array([ 144.,    0.,  483.,    0.,  783.,    0., 1320.,    0., 2103.,
#         2557.]),
#  array([10. , 10.5, 11. , 11.5, 12. , 12.5, 13. , 13.5, 14. , 14.5, 15. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots()
ax.hist(df['comb08'],range=(10,15), histtype='step', orientation='horizontal')
# Out:
# (array([ 144.,    0.,  483.,    0.,  783.,    0., 1320.,    0., 2103.,
#         2557.]),
#  array([10. , 10.5, 11. , 11.5, 12. , 12.5, 13. , 13.5, 14. , 14.5, 15. ]),
#  [<matplotlib.patches.Polygon at 0x71d91936c980>])

# %%
fig, ax = plt.subplots()
n, bin, patches = ax.hist(df['comb08'], range=(10,50))
print(n)
print(bin)
# Out:
# [ 2730. 10585. 16324.  9820.  4485.  1736.   567.   271.    98.   128.]
# [10. 14. 18. 22. 26. 30. 34. 38. 42. 46. 50.]

# %%
fig, ax = plt.subplots(2)
ax[0].hist(df["comb08"], range(10, 50))
ax[1].hist(df["comb08"], range(10,100))
# Out:
# (array([1.440e+02, 4.830e+02, 7.830e+02, 1.320e+03, 2.103e+03, 2.557e+03,
#         2.821e+03, 3.104e+03, 4.274e+03, 4.131e+03, 3.874e+03, 4.045e+03,
#         3.012e+03, 2.607e+03, 2.211e+03, 1.990e+03, 1.611e+03, 1.163e+03,
#         9.680e+02, 7.430e+02, 6.840e+02, 3.910e+02, 3.970e+02, 2.640e+02,
#         2.330e+02, 1.450e+02, 1.230e+02, 6.600e+01, 5.800e+01, 6.200e+01,
#         8.700e+01, 6.400e+01, 4.900e+01, 2.400e+01, 2.500e+01, 0.000e+00,
#         3.000e+01, 2.900e+01, 2.400e+01, 1.400e+01, 3.100e+01, 1.000e+00,
#         3.700e+01, 9.000e+00, 1.300e+01, 7.000e+00, 8.000e+00, 7.000e+00,
#         7.000e+00, 2.000e+00, 1.000e+00, 5.000e+00, 2.000e+00, 1.000e+01,
#         4.000e+00, 1.000e+01, 3.000e+00, 6.000e+00, 1.900e+01, 4.000e+00,
#         9.000e+00, 2.000e+00, 1.200e+01, 1.800e+01, 8.000e+00, 1.800e+01,
#         1.500e+01, 1.300e+01, 2.200e+01, 1.100e+01, 1.400e+01, 8.000e+00,
#         1.300e+01, 1.500e+01, 1.000e+01, 1.300e+01, 1.500e+01, 1.500e+01,
# ...

# %%
fig , ax = plt.subplots()
ax.boxplot(df["comb08"], labels=["All"])
ax.set(title="Vehicle MPG", ylabel="MPG for vehicle")
# Out:
# /tmp/ipykernel_6971/2208260008.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(df["comb08"], labels=["All"])
# [Text(0.5, 1.0, 'Vehicle MPG'), Text(0, 0.5, 'MPG for vehicle')]

# %%
fig , ax = plt.subplots()
ax.boxplot(df["comb08"], labels=["All"], showfliers=False)
ax.set(title="Vehicle MPG", ylabel="MPG for vehicle")
# Out:
# /tmp/ipykernel_6971/2982195680.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(df["comb08"], labels=["All"], showfliers=False)
# [Text(0.5, 1.0, 'Vehicle MPG'), Text(0, 0.5, 'MPG for vehicle')]

# %%
fig , (ax1, ax2) = plt.subplots(2)
ax1.hist(df["comb08"], range=(10,100))
ax1.set(title="Vehicle MPG", xlabel="MPG for vehicle", ylabel="Number of vehicle")

ax2.boxplot(df["comb08"], labels=["All"], showfliers=False)
ax1.set(title="Vehicle MPG", ylabel="MPG for vehicle")
# Out:
# /tmp/ipykernel_6971/2983607773.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax2.boxplot(df["comb08"], labels=["All"], showfliers=False)
# [Text(0.5, 1.0, 'Vehicle MPG'), Text(0, 0.5, 'MPG for vehicle')]

# %%
fig , (ax1, ax2) = plt.subplots(2)
ax1.hist(df["comb08"], range=(10,100))
ax1.set(title="Vehicle MPG", xlabel="MPG for vehicle", ylabel="Number of vehicle")

ax2.boxplot(df["comb08"], labels=["All"], showfliers=False, vert=False)
ax2.set(ylabel="MPG for vehicle")

fig.suptitle("MPG Distribution", fontsize=14, fontweight="bold")
# Out:
# /tmp/ipykernel_6971/3853401324.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax2.boxplot(df["comb08"], labels=["All"], showfliers=False, vert=False)
# Text(0.5, 0.98, 'MPG Distribution')

# %%
fig , (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,4))
ax1.hist(df["comb08"], range=(10,100))
ax1.set(title="Vehicle MPG",ylabel="Number of vehicle")

ax2.boxplot(df["comb08"], labels=["All"], showfliers=False)
ax2.set(ylabel="MPG for vehicle")

fig.suptitle("MPG Distribution", fontsize=14, fontweight="bold")
# Out:
# /tmp/ipykernel_6971/3800889889.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax2.boxplot(df["comb08"], labels=["All"], showfliers=False)
# Text(0.5, 0.98, 'MPG Distribution')

# %%
avg_by_year = df.groupby(['year'],as_index=False).agg({'comb08':'mean'}).round(2)
avg_by_year
# Out:
#     year  comb08
# 0   1984   19.88
# 1   1985   19.81
# 2   1986   19.55
# 3   1987   19.23
# 4   1988   19.33
# 5   1989   19.13
# 6   1990   19.00
# 7   1991   18.83
# 8   1992   18.86
# 9   1993   19.10
# 10  1994   19.01
# 11  1995   18.80
# 12  1996   19.58
# 13  1997   19.43
# 14  1998   19.52
# 15  1999   19.61
# 16  2000   19.53
# 17  2001   19.48
# 18  2002   19.17
# 19  2003   19.00
# 20  2004   19.07
# 21  2005   19.19
# 22  2006   18.96
# 23  2007   18.98
# 24  2008   19.28
# 25  2009   19.74
# 26  2010   20.59
# 27  2011   21.01
# 28  2012   21.78
# 29  2013   23.12
# 30  2014   23.55
# 31  2015   24.04
# 32  2016   25.17
# 33  2017   25.33
# 34  2018   25.06
# 35  2019   25.75
# 36  2020   26.01
# 37  2021   26.29
# 38  2022   28.20
# 39  2023   30.97
# 40  2024   36.51
# 41  2025   25.49

# %%
fig, ax = plt.subplots()
ax.plot(avg_by_year['year'], avg_by_year['comb08']);

# %%
fig, ax = plt.subplots()
ax.plot(avg_by_year['year'], avg_by_year['comb08'])
ax.set_xticks(np.arange(1984,2025, 10))

# %%
fig, ax = plt.subplots()
ax.bar(avg_by_year['year'], avg_by_year['comb08'])
# Out:
# <BarContainer object of 42 artists>

# %%
fig, ax = plt.subplots()
ax.bar(avg_by_year['year'], avg_by_year['comb08'])
ax.set_xticks(np.arange(1984,2025, 10))

# %%
fig, ax = plt.subplots()
ax.barh(avg_by_year['year'], avg_by_year['comb08'])
# Out:
# <BarContainer object of 42 artists>

# %%
fig, ax = plt.subplots()
ax.scatter(x=df['fuelCost08'], y=df['displ'], c=df['cylinders'])
ax.set_xlabel('Cost')
ax.set_ylabel('Displacement')
# Out:
# Text(0, 0.5, 'Displacement')

# %%
fig, ax = plt.subplots()
ax.scatter(x=df['fuelCost08'], y=df['displ'], c=df['cylinders'])
ax.set_xlabel('Cost')
ax.set_ylabel('Displacement')
ax.xaxis.set_major_formatter("${x:,.0f}")

# %%
ax.set_ylabel('Displacement')
fig, ax = plt.subplots()
ax.scatter(x=df['fuelCost08'], y=df['displ'], c=df['cylinders'])
ax.set_xlabel('Cost')
ax.set_ylabel('Displacement')
ax.xaxis.set_major_formatter("${x:,.0f}")
ax.tick_params(axis='x', labelrotation=45, labelsize=14)
ax.tick_params(axis='x', labelsize=14)

# %%
ax.set_ylabel('Displacement')
fig, ax = plt.subplots()
ax.scatter(x=df['fuelCost08'], y=df['displ'], c=df['cylinders'])
ax.set_xlabel('Cost')
ax.set_ylabel('Displacement')
ax.xaxis.set_major_formatter("${x:,.0f}")
ax.tick_params(axis='x', labelrotation=45, labelsize=14)
ax.tick_params(axis='x', labelsize=14)
ax.axvline(6500, color='red')
