# %%
import pandas as pd
import numpy as np
import scipy
import scipy.stats as sp
import matplotlib.pyplot as plt
import seaborn as sns
import pylab

# %%
ds_students = pd.read_csv("datasets/student-mat.csv")
ds_students
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# if p-value > 0.05 -> normally distributed

# %% [markdown]
# if p-value < 0.05 -> not normal

# %%
sp.shapiro(ds_students['G3'])
# Out:
# ShapiroResult(statistic=0.928729849872698, pvalue=8.835916843805374e-13)

# %% [markdown]
# if statistic > critical_values -> not same as dist

# %%
sp.anderson(ds_students['G3'], dist='norm')
# Out:
# AndersonResult(statistic=8.30320458141631, critical_values=array([0.57 , 0.65 , 0.779, 0.909, 1.081]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=10.415189873417722, scale=4.5814426109978434)
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')

# %%
ds_students["G3"].hist()
# Out:
# <Axes: >

# %%
sp.probplot(ds_students['G3'], dist= 'norm', plot=pylab)
pylab.show()
