# %%
import pandas as pd
import numpy as np
import scipy
import scipy.stats as sp
import matplotlib.pyplot as plt
import seaborn as sns
from ab_test_permutive import ab_test

# %%
market_ds = pd.read_csv("../datasets/marketing_AB.csv")

# %%
market_ds
# Out:
#         Unnamed: 0  user id test group  converted  total ads most ads day  \
# 0                0  1069124         ad      False        130       Monday
# 1                1  1119715         ad      False         93      Tuesday
# 2                2  1144181         ad      False         21      Tuesday
# 3                3  1435133         ad      False        355      Tuesday
# 4                4  1015700         ad      False        276       Friday
# ...            ...      ...        ...        ...        ...          ...
# 588096      588096  1278437         ad      False          1      Tuesday
# 588097      588097  1327975         ad      False          1      Tuesday
# 588098      588098  1038442         ad      False          3      Tuesday
# 588099      588099  1496395         ad      False          1      Tuesday
# 588100      588100  1237779         ad      False          1      Tuesday
#
#         most ads hour
# 0                  20
# 1                  22
# ...

# %%
group_a = market_ds[
    (market_ds['test group'] == 'ad')
    &
    (market_ds['converted'].notnull())
]['converted']
group_a
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 588096    False
# 588097    False
# 588098    False
# 588099    False
# 588100    False
# Name: converted, Length: 564577, dtype: bool

# %%
group_b = market_ds[
    (market_ds['test group'] == 'psa')

]['converted']
group_b
# Out:
# 18        False
# 38        False
# 68        False
# 140       False
# 157       False
#           ...
# 588052    False
# 588063    False
# 588066    False
# 588069    False
# 588081    False
# Name: converted, Length: 23524, dtype: bool

# %%
group_a.mean()
# Out:
# 0.025546559636683747

# %%
group_b.mean()
# Out:
# 0.01785410644448223

# %% [markdown]
# Bad dataset

# %%
ab_test(group_a, group_b, 1000)
# Out:
# 0.0
